# %% [markdown]
# # Movie Genre Data Analysis

# %% [markdown]
# ## Introduction
# We are going to focus highly on genre's. I want to know everything about Genre's.
#
# Here are some things I want to look at:
# ### Research Questions (Q):
#
# 1. Which genres are the most common (number of movies made)?
# 2. Which genres have high avg. budget and revenue?
# 3. Which genres have high avg. profit
# 4. Which genres have high avg. popularity?
# 5. Which genres have highest number of movies with an voting avg. >=8?
# 6. What is the profit per genre per year
#
#
#
# ### Research Hypotheses (H):
#
# 1. The best movies according to vote avg. return high profit and revenue.
# 2. The best movies according to popularity return high profit and revenue.
# 3. Highly budgeted movies return high revenue and profit.
# 4. Highly budgeted movies have a high popularity.

# %%
import pandas as pd

movies = pd.read_csv(r"C:\Users\hunte\Documents\Analyst Workshop\Pandas_For_Data_Analysis\11. Real World Data Analysis Projects\Movie Genres\imdb_movies.csv")

# %%
pd.set_option('display.max.rows', 11000)
pd.set_option('display.max.columns', 22)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies[movies.duplicated()]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951    0.596430  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  \
# 2090  Dwight H. Little  Survival is no game
#
#                                                keywords  \
# 2090  martial arts|dystopia|based on video game|mart...
#
#                                                overview  runtime  \
# 2090  In the year of 2039, after World Wars destroy ...       92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date  vote_count  vote_average  release_year      budget_adj  \
# 2090      3/20/10         110      5.000000          2010 30000000.000000
#
#        revenue_adj
# 2090 967000.000000

# %%
movies.drop_duplicates(inplace=True)

# %%
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, popularity, budget, revenue, original_title, cast, homepage, director, tagline, keywords, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, budget_adj, revenue_adj]
# Index: []

# %%
movies.dropna(subset=['genres'], inplace=True)

# %%
movies['profit'] = movies['revenue']-movies['budget']

# %%
movie_genre = movies[['popularity','budget','revenue','original_title','runtime','genres','release_year','vote_count','vote_average','profit']]

# %%
movie_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres  release_year  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller          2015        5562
# 1  Action|Adventure|Science Fiction|Thriller          2015        6185
# 2         Adventure|Science Fiction|Thriller          2015        2480
# 3   Action|Adventure|Science Fiction|Fantasy          2015        5292
# 4                      Action|Crime|Thriller          2015        2947
#
#    vote_average      profit
# 0      6.500000  1363528810
# ...

# %%
from pandas import Series, DataFrame

# %%
split = movie_genre['genres'].str.split('|').apply(Series, 1).stack()
split.index = split.index.droplevel(-1)
split.name = 'genres_split'
del movie_genre['genres']
movie_genre = movie_genre.join(split)
# Out:
# C:\Users\hunte\AppData\Local\Temp\ipykernel_20812\3413607571.py:1: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   split = movie_genre['genres'].str.split('|').apply(Series, 1).stack()

# %%
movie_genre.head(20)
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 2   13.112507  110000000   295238201                     Insurgent      119
# 2   13.112507  110000000   295238201                     Insurgent      119
# ...

# %% [markdown]
# ### Research Questions (Q):
#
# 1. Which genres are the most common (number of movies made)?
#
# Answer: The genres that are most common are Drama, Comedy, Thriller, and Action

# %%
genres_count = pd.DataFrame(movie_genre.groupby('genres_split').original_title.nunique()).sort_values('original_title', ascending = True)

# %%
genres_count
# Out:
#                  original_title
# genres_split
# Western                     163
# TV Movie                    167
# Foreign                     188
# War                         269
# History                     331
# Music                       403
# Documentary                 520
# Animation                   697
# Mystery                     796
# Fantasy                     899
# Science Fiction            1207
# Family                     1211
# Crime                      1337
# Adventure                  1442
# Horror                     1580
# Romance                    1686
# Action                     2339
# Thriller                   2841
# Comedy                     3750
# Drama                      4672

# %%
genres_count['original_title'].plot.pie(title = 'Movies Per Genre in %', autopct = '%1.1f', figsize = (10,10))
# Out:
# <Axes: title={'center': 'Movies Per Genre in %'}, ylabel='original_title'>

# %%
genres_count['original_title'].plot.barh(title = 'Movies Per Genre', color = 'Darkblue', figsize = (10,9))
# Out:
# <Axes: title={'center': 'Movies Per Genre'}, ylabel='genres_split'>

# %% [markdown]
# 2. Which genres have high avg. budget and revenue?
#
# Answer: The genres that have high avg. budget and revenue are Adventure, Fantasy, and Action

# %%
genres_avg = movie_genre.groupby('genres_split').mean(numeric_only=True)
pd.options.display.float_format = '{:2f}'.format
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# Action             0.926274 27727820.331376  72794732.002517 104.917785
# Adventure          1.154259 37543694.530931 113137861.069341 106.173351
# Animation          0.852182 23159781.606581  75256062.223176  68.181688
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Family             0.786668 23359337.420796  72433176.373680  89.603574
# Fantasy            0.992840 32612585.348253  96313657.081878 100.736900
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# ...

# %%
genres_avg.sort_values('budget', ascending = True, inplace = True)

# %%
genres_avg[['budget', 'revenue']].plot.barh(title = 'Budget and Revenue by Genre', color = ('Darkblue','c'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Budget and Revenue by Genre'}, ylabel='genres_split'>

# %% [markdown]
# 3. Which genres have high avg. profit
#
# Answer: The genres that have high avg. profit are Adventure, Fantasy, and Animation

# %%
genres_avg.sort_values('profit', ascending = True, inplace = True)

# %%
genres_avg[['profit']].plot.barh(title = 'Profit by Genre', color = ('Darkblue','c'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Profit by Genre'}, ylabel='genres_split'>

# %% [markdown]
# 4. Which genres have high avg. popularity?
#
# Answer: The genres that have high avg. popularity are Adventure, Science Fiction, and Fantasy.

# %%
genres_avg.sort_values('popularity', ascending = True, inplace = True)

# %%
genres_avg[['popularity']].plot.barh(title = 'Popularity by Genre', color = ('Darkblue','c'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Popularity by Genre'}, ylabel='genres_split'>

# %% [markdown]
# 5. Which genres have highest number of movies with a voting avg. >=8?
#
# Answer: The genres that have the highest number of movies with a voting avg. >=8 are Drama, Crime, and Documentary.

# %%
movie_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year  vote_count  vote_average      profit     genres_split
# 0          2015        5562      6.500000  1363528810           Action
# 0          2015        5562      6.500000  1363528810        Adventure
# 0          2015        5562      6.500000  1363528810  Science Fiction
# 0          2015        5562      6.500000  1363528810         Thriller
# 1          2015        6185      7.100000   228436354           Action

# %%
voting_avg = movie_genre[(movie_genre['vote_average'] >= 8) & (movie_genre['vote_count'] >= 50)]
voting_avg.head()
# Out:
#     popularity     budget    revenue original_title  runtime  release_year  \
# 9     6.326804  175000000  853708609     Inside Out       94          2015
# 9     6.326804  175000000  853708609     Inside Out       94          2015
# 9     6.326804  175000000  853708609     Inside Out       94          2015
# 35    3.557846    6000000   35401758           Room      117          2015
# 35    3.557846    6000000   35401758           Room      117          2015
#
#     vote_count  vote_average     profit genres_split
# 9         3935      8.000000  678708609       Comedy
# 9         3935      8.000000  678708609    Animation
# 9         3935      8.000000  678708609       Family
# 35        1520      8.000000   29401758        Drama
# 35        1520      8.000000   29401758     Thriller

# %%
genres_vote = voting_avg.groupby('genres_split').size().sort_values(ascending=True)
pd.DataFrame(genres_vote)
# Out:
#                   0
# genres_split
# Mystery           1
# Horror            1
# Fantasy           2
# Music             2
# History           2
# Science Fiction   3
# Romance           3
# Action            3
# Comedy            3
# War               3
# Adventure         4
# Animation         5
# Family            5
# Thriller          6
# Documentary       7
# Crime            10
# Drama            21

# %%
genres_vote.plot.barh(title = 'Vote Average by Genre', color = 'DarkBlue',figsize = (10,9))
# Out:
# <Axes: title={'center': 'Vote Average by Genre'}, ylabel='genres_split'>

# %% [markdown]
# 6. What is the profit per genre per year

# %%
movie_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year  vote_count  vote_average      profit     genres_split
# 0          2015        5562      6.500000  1363528810           Action
# 0          2015        5562      6.500000  1363528810        Adventure
# 0          2015        5562      6.500000  1363528810  Science Fiction
# 0          2015        5562      6.500000  1363528810         Thriller
# 1          2015        6185      7.100000   228436354           Action

# %%
time_genre = pd.DataFrame(movie_genre.groupby(['release_year','genres_split'])['profit'].mean())

# %%
time_genre.head(50)
# Out:
#                                        profit
# release_year genres_split
# 1960         Action            6363125.000000
#              Adventure          431000.000000
#              Comedy            5258750.000000
#              Crime                   0.000000
#              Drama             8245619.384615
#              Family            3333333.333333
#              Fantasy           -375000.000000
#              Foreign                 0.000000
#              History           9600000.000000
#              Horror            4389007.428571
#              Music                   0.000000
#              Romance           5225000.000000
#              Science Fiction   -316666.666667
#              Thriller          5028842.000000
#              War                     0.000000
#              Western            484166.666667
# 1961         Action            2457142.857143
#              Adventure        39130002.333333
#              Animation       211880014.000000
# ...

# %%
final_genre = pd.pivot_table(time_genre, values = 'profit', index = ['genres_split'], columns = ['release_year'])

# %%
final_genre.head(10)
# Out:
# release_year           1960             1961            1962            1963  \
# genres_split
# Action       6363125.000000   2457142.857143 10437500.000000 14999691.250000
# Adventure     431000.000000  39130002.333333 21214285.714286  9428395.000000
# Animation               NaN 211880014.000000             NaN        0.000000
# Comedy       5258750.000000  22198001.400000  1599974.800000   765591.923077
# Crime              0.000000  18828411.000000  3709948.666667   369526.750000
# Documentary             NaN              NaN             NaN             NaN
# Drama        8245619.384615   4912698.375000  4373796.190476  1587307.692308
# Family       3333333.333333  42576002.800000  4000000.000000  -333333.333333
# Fantasy      -375000.000000         0.000000     -126.000000  -500000.000000
# Foreign            0.000000         0.000000     -126.000000        0.000000
#
# release_year            1964            1965           1966             1967  \
# genres_split
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc = {'figure.figsize':(15,10)})
sns.heatmap(final_genre, cmap = 'YlGnBu', linewidths = .5)
plt.title('Genres by Profit per Year')
# Out:
# Text(0.5, 1.0, 'Genres by Profit per Year')

# %% [markdown]
# ### Research Hypotheses (H):
#
# 1. The best movies according to vote avg. return high profit and revenue.
#
# The hypothesis was slightly off as the correlation was quite slim

# %%
movies.drop_duplicates(inplace = True)
movies['profit'] = movies['revenue'] - movies['budget']
movies_genre = movies[['popularity','budget','revenue','original_title','runtime','genres','release_date', 'release_year','vote_count','vote_average','profit']]

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  release_year  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15          2015
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15          2015
# 2         Adventure|Science Fiction|Thriller      3/18/15          2015
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15          2015
# 4                      Action|Crime|Thriller       4/1/15          2015
#
#    vote_count  vote_average      profit
# ...

# %%
movies_counted = movies_genre[movies_genre['vote_count']>= 50]
movies_counted.corr(method='spearman', numeric_only= True)
# Out:
#               popularity    budget   revenue   runtime  release_year  \
# popularity      1.000000  0.484952  0.588594  0.230214      0.070895
# budget          0.484952  1.000000  0.714733  0.360001     -0.019452
# revenue         0.588594  0.714733  1.000000  0.341469     -0.108974
# runtime         0.230214  0.360001  0.341469  1.000000     -0.131512
# release_year    0.070895 -0.019452 -0.108974 -0.131512      1.000000
# vote_count      0.768888  0.554412  0.682550  0.263164      0.149045
# vote_average    0.189226 -0.044050  0.112201  0.286082     -0.153545
# profit          0.498092  0.334345  0.842278  0.211947     -0.099378
#
#               vote_count  vote_average    profit
# popularity      0.768888      0.189226  0.498092
# budget          0.554412     -0.044050  0.334345
# revenue         0.682550      0.112201  0.842278
# runtime         0.263164      0.286082  0.211947
# release_year    0.149045     -0.153545 -0.099378
# ...

# %%
movies_counted.plot.scatter(x = 'vote_average',y = 'profit')
# Out:
# <Axes: xlabel='vote_average', ylabel='profit'>

# %%
import seaborn as sns

# %%
sns.regplot(x = 'vote_average', y = 'profit', data = movies_counted, line_kws = {'color':'red'})
# Out:
# <Axes: xlabel='vote_average', ylabel='profit'>

# %%
sns.regplot(x = 'vote_average', y = 'revenue', data = movies_counted, line_kws = {'color':'red'})
# Out:
# <Axes: xlabel='vote_average', ylabel='revenue'>

# %% [markdown]
# 2. The best movies according to popularity return high profit and revenue.
#
# This hypothesis was correct and it shows strongly in the scatter plot below

# %%
movies_counted.corr(method='spearman', numeric_only = True)
# Out:
#               popularity    budget   revenue   runtime  release_year  \
# popularity      1.000000  0.484952  0.588594  0.230214      0.070895
# budget          0.484952  1.000000  0.714733  0.360001     -0.019452
# revenue         0.588594  0.714733  1.000000  0.341469     -0.108974
# runtime         0.230214  0.360001  0.341469  1.000000     -0.131512
# release_year    0.070895 -0.019452 -0.108974 -0.131512      1.000000
# vote_count      0.768888  0.554412  0.682550  0.263164      0.149045
# vote_average    0.189226 -0.044050  0.112201  0.286082     -0.153545
# profit          0.498092  0.334345  0.842278  0.211947     -0.099378
#
#               vote_count  vote_average    profit
# popularity      0.768888      0.189226  0.498092
# budget          0.554412     -0.044050  0.334345
# revenue         0.682550      0.112201  0.842278
# runtime         0.263164      0.286082  0.211947
# release_year    0.149045     -0.153545 -0.099378
# ...

# %%
import matplotlib.pyplot as plt
sns.regplot(x = 'popularity', y = 'revenue', data = movies_counted, line_kws = {'color':'red'})
plt.figure(figsize = (10,15))
plt.show()

# %% [markdown]
# 3. Highly budgeted movies return high revenue and profit.
#
# This hypothesis was accurate. The scatterplot below shows a healthy correlation.

# %%
movies_counted.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  release_year  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15          2015
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15          2015
# 2         Adventure|Science Fiction|Thriller      3/18/15          2015
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15          2015
# 4                      Action|Crime|Thriller       4/1/15          2015
#
#    vote_count  vote_average      profit
# ...

# %%
sns.regplot(x = 'budget', y = 'profit', data = movies_counted, line_kws = {'color':'red'})
plt.figure(figsize = (10,15))
plt.show()

# %% [markdown]
# 4. Highly budgeted movies have a high popularity.
#
# As the budget increases, it does not increase its popularity that much.
# There are some outliers in the data that may compliment the hypothesis in terms of the correlation

# %%
sns.regplot(x = 'budget', y = 'popularity', data = movies_counted, line_kws = {'color':'red'})
plt.figure(figsize = (10,15))
plt.show()

# %% [markdown]
# # Research Questions and Hypotheses
#
# ## Research Questions
#
# 1. **Which genres are the most common (number of movies made)?**
#    - The genres that are most common are Drama, Comedy, Thriller, and Action.
#
# 2. **Which genres have high average budget and revenue?**
#    - The genres with high average budget and revenue are Adventure, Fantasy, and Action.
#
# 3. **Which genres have high average profit?**
#    - The genres with high average profit are Adventure, Fantasy, and Animation.
#
# 4. **Which genres have high average popularity?**
#    - The genres with high average popularity are Adventure, Science Fiction, and Fantasy.
#
# 5. **Which genres have the highest number of movies with a voting average ≥ 8?**
#    - The genres with the highest number of movies with a voting average ≥ 8 are Drama, Crime, and Documentary.
#
# ## Research Hypotheses
#
# 1. **The best movies according to vote average return high profit and revenue.**
#    - This hypothesis was slightly off, as the correlation was slim.
#
# 2. **The best movies according to popularity return high profit and revenue.**
#    - This hypothesis was correct, strongly supported by the scatter plot.
#
# 3. **Highly budgeted movies return high revenue and profit.**
#    - This hypothesis was accurate, as shown by a healthy correlation in the scatter plot.
#
# 4. **Highly budgeted movies have high popularity.**
#    - This hypothesis was partially accurate; while there is some correlation, the relationship is weaker, with notable outliers influencing the trend.
